# %% [markdown]
# Proposed workflow
#
# Since the data is not ready, I will explore subjectivity detection first.
#
# Picture source: https://www.researchgate.net/publication/343654268_Subjectivity_Detection_for_Sentiment_Analysis_on_Twitter_Data
#
# This step is introduced to achieve higher accuracy. The pre-processed data is taken and is classified into subjective or objective statement using a subjectivity classifier. All the tweets having a subjectivity score lesser than the specified threshold are filtered out, and the classifier is trained with only the remaining tweets.

# %% [markdown]
# ![structure.PNG](attachment:structure.PNG)

# %%
# Now is still subjectivity detection, so no need go in depth first
# It is the subjective / objective that we need to go in depth

# %%
# Approach 1
from textblob import TextBlob
testimonial = TextBlob("Textblob is amazingly simple to use. What great fun!")
testimonial.sentiment

# testimonial.sentiment.polarity
# testimonial.sentiment.subjectivity
# The polarity score is a float within the range [-1.0, 1.0]. 
# The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
# Out:
# Sentiment(polarity=0.39166666666666666, subjectivity=0.4357142857142857)

# %%
# Approach 2
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentences = ["Textblob is amazingly simple to use. What great fun!",
            "I am an university student."]

sid = SentimentIntensityAnalyzer()
for sentence in sentences:
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print("\n")

# https://github.com/cjhutto/vaderSentiment#about-the-scoring
# positive sentiment: compound score >= 0.05
# neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
# negative sentiment: compound score <= -0.05
# Out:
# Textblob is amazingly simple to use. What great fun!
# compound: 0.8268, neg: 0.0, neu: 0.476, pos: 0.524,
#
# I am an university student.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,

# %%
# Out:
# Textblob is amazingly simple to use. What great fun!
# compound: 0.8268, neg: 0.0, neu: 0.476, pos: 0.524,
